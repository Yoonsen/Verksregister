# %% [markdown]
# # Create and evaluate a corpus of books
#
# The corpus is taken from the works-registry, and the evaluation selects books that belong to different epochs, where each epoch is defined by the variable `matrix`. This variable contains a dataframe with columns corresponding to epochs and rows are words with different weights within the epoch.

# %%
import dhlab.module_update as mu
import dhlab.text as dh
import pandas as pd
import verk as v
import evaluate_corpus as ev
import json
import os

# %%
mu.css()
# Out:
# <style>@import url(http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# p {
#     font-size:1.3em;
#     font-family:serif;
#     line-height:1.4em;
#     color:#142850;
# }
# h1, h2, h3, h4 {
#     color:#27496d;
# }
#
# /*
# .prompt, .jp-InputPrompt, .jp-InputArea-prompt, .jp-OutputPrompt, .jp-OutputArea-prompt {
#     visibility: hidden;
# }
#
#
# .jp-CodeCell .jp-Notebook-cell    {
#     margin-left:10%;
#     margin-right:5%;
# }
#
#
# .jp-InputArea, .jp-OutputArea {
#     margin-left:2.5em;
#     margin-right:2.5em;
# }
# */
#
#
# body  {
#     margin:10%;
#     counter-reset: h1counter;
#
# }
#
# /* .jp-MarkdownOutput, .text_cell_render {
#
#     background-color:#FEFBF1;
#     border-style: solid;
#     border-width: 1px;
#     border-color: rgba(0,0,0, 0.10);;
# } */
#
#
# h1:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 50%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:3px solid SlateGray; /* FireBrick; */
# }
#
# h2:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 30%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:2px solid SlateGray; /* FireBrick; */
# }
#
# </style>

# %% [markdown]
# The process is this
#
# 1. Create a matrix
# 2. Find works
# 3. Evaluate the works against the matrix
# 4. Create a parallell corpus from the evaluation

# %%
matrix = pd.read_csv("old_vs_new_word_list.csv", index_col = 0)

# %% [markdown]
# Create a list of books from know authors or books. This can be done by an exhaustive search or by more contentrated search.

# %%
authors = ["bjørnstjerne bjørnson",  "cora sandel", "goethe", "nietsche", "henrik ibsen", "amalie skram", "alexander kielland", "jonas lie", "camilla collett"]

# %%
authors += [  "sigrid undset", "knut hamsun", "Per Christen Asbjørnsen","Arne Garborg ", "hulda garborg","Henrik Wergeland", "Sigbjørn Obstfelder" ]

# %%
author_corpus = {
    auth: dh.Corpus(doctype="digibok", author= auth, limit = 1000, to_year = 1920, lang='nob') for auth in authors
}

# %% [markdown]
# Here is what the `author_corpus` looks like

# %% [markdown]
# Find the works identifiers, here stored in the variable `works`, from the list of authors, and then looping through the titles.

# %%
works = []
for a in author_corpus: 
    for t in author_corpus[a].corpus.title:
        try:
            works.extend(v.find_works(a, t)['id'].values)
        except:
            pass

# %% [markdown]
# From this list of different works a parallell corpus is created, using the matrix to find modernized versions.

# %% [markdown]
# import importlib
# importlib.reload(v)
# importlib.reload(ev)

# %% [markdown]
# Go through the works list and see if there are URNs in the list. Keep those works with more than one URN

# %%
len(works)
# Out:
# 428

# %%
parallel_candidates = {works_id: v.urns_for_works(works_id) for works_id in works}

# %%
candidates = {x:parallel_candidates[x] for x in parallel_candidates if len(parallel_candidates[x]) > 1}

# %%
candidates[list(candidates.keys())[3]]
# Out:
# ['URN:NBN:no-nb_digibok_2008040200034', 'URN:NBN:no-nb_digibok_2012030524009']

# %%
import importlib
importlib.reload(ev)
# Out:
# <module 'evaluate_corpus' from '/mnt/disk1/Github/Verksregister/evaluate_corpus.py'>

# %%
c = dh.CorpusFromIdentifiers(candidates[list(candidates.keys())[2]])

# %%
c.corpus
# Out:
#      dhlabid           title                                   authors  \
# 0  100444984  Digte og sange  Bjørnson , Bjørnstjerne / Bull , Francis
#
#                                    urn                                oaiid  \
# 0  URN:NBN:no-nb_digibok_2008051301010  oai:nb.bibsys.no:999102893874702202
#
#                             sesamid isbn10  city  timestamp  year  publisher  \
# 0  e43e126fe3d40d5c970808423d60eb80         Oslo   19570101  1957  Gyldendal
#
#   langs subjects     ddc  genres      literaryform  doctype
# 0   nob           839.91  poetry  Skjønnlitteratur  digibok

# %%
ev.evaluate_corpus_norwegian(corpus = c, matrix=matrix, top_number = 10)
# Out:
# {'URN:NBN:no-nb_digibok_2008051301010': ('1990', 0.10874372971463508)}

# %%
evals = {}
for worksid in candidates:
    try:
        evals[worksid] = ev.evaluate_corpus_norwegian(corpus = dh.CorpusFromIdentifiers(candidates[worksid]), matrix = matrix)
    except KeyboardInterrupt:
        break
    except:
        pass

# %%
triple = {}
for i in evals:
    data = evals[i]
    old = [x for x in data if int(data[x][0]) <= 1900 ]
    new = [x for x in data if int(data[x][0]) > 1900 ] 
    if old != [] and new != []:
        triple[i] = (old, new)

# %%
triple
# Out:
# {'262824678d4b0e2d8695df21b6d920c786cd5c019dcb82ad99b458b057e3d243': (['URN:NBN:no-nb_digibok_2012102107020'],
#   ['URN:NBN:no-nb_digibok_2009022600051',
#    'URN:NBN:no-nb_digibok_2008060904035']),
#  '396ddc56ae4b19a533550b9d63df04bd9c25c8675ae3768ac9f1aead4f0e3b56': (['URN:NBN:no-nb_digibok_2012070408109',
#    'URN:NBN:no-nb_digibok_2010021803059',
#    'URN:NBN:no-nb_digibok_2011031012001'],
#   ['URN:NBN:no-nb_digibok_2012070905001',
#    'URN:NBN:no-nb_digibok_2010032213006',
#    'URN:NBN:no-nb_digibok_2008052204119',
#    'URN:NBN:no-nb_digibok_2006082900066',
#    'URN:NBN:no-nb_digibok_2010070106207',
#    'URN:NBN:no-nb_digibok_2006082400043',
#    'URN:NBN:no-nb_digibok_2008051504087',
#    'URN:NBN:no-nb_digibok_2008061900071',
#    'URN:NBN:no-nb_digibok_2009062204013']),
#  '50479b0cfbc89d081154db811ba107c616c1d20bf9e650b898e2d7554bb0f1ab': (['URN:NBN:no-nb_digibok_2008031404070',
#    'URN:NBN:no-nb_digibok_2008071812003'],
#   ['URN:NBN:no-nb_digibok_2011120108006']),
#  '1d4ea7e02197c411eb6670d943664e88beded896e11093af4063c9a5c13d7211': (['URN:NBN:no-nb_digibok_2012070408109',
#    'URN:NBN:no-nb_digibok_2011031012001'],
#   ['URN:NBN:no-nb_digibok_2006082400043',
#    'URN:NBN:no-nb_digibok_2010070106207',
#    'URN:NBN:no-nb_digibok_2012070905001',
#    'URN:NBN:no-nb_digibok_2009022600051',
#    'URN:NBN:no-nb_digibok_2010032213006',
#    'URN:NBN:no-nb_digibok_2008051504087',
#    'URN:NBN:no-nb_digibok_2008060904035',
#    'URN:NBN:no-nb_digibok_2008061900071']),
#  '4405c68f5bb3e077ec405b10d5c5df9ed097eb20adaddfdc052d1215a05b1c5c': (['URN:NBN:no-nb_digibok_2008070812004'],
#   ['URN:NBN:no-nb_digibok_2006080900015',
#    'URN:NBN:no-nb_digibok_2009062200004']),
#  'e9764ff2f8b1631cbc170f266eb4120cdbcc8f60f6df060f1f0000da19671aac': (['URN:NBN:no-nb_digibok_2012070408109',
#    'URN:NBN:no-nb_digibok_2011031012001'],
#   ['URN:NBN:no-nb_digibok_2012070905001',
#    'URN:NBN:no-nb_digibok_2008061900071',
#    'URN:NBN:no-nb_digibok_2010070106207',
#    'URN:NBN:no-nb_digibok_2006082400043',
#    'URN:NBN:no-nb_digibok_2006082800014',
#    'URN:NBN:no-nb_digibok_2014032738014',
#    'URN:NBN:no-nb_digibok_2011120108006']),
#  '02a6637e43b34acd12443f4d12e62c10166f8ad37941434bcc747782e7dbf16c': (['URN:NBN:no-nb_digibok_2008072412003',
#    'URN:NBN:no-nb_digibok_2014092506034'],
#   ['URN:NBN:no-nb_digibok_2008070800097',
#    'URN:NBN:no-nb_digibok_2008020500112']),
#  '64a2844abe6d7b78619b7c6fbb21039e8e9243fdb4a54a1690fc00674bd8a8cb': (['URN:NBN:no-nb_digibok_2008040300020'],
#   ['URN:NBN:no-nb_digibok_2011060606014',
#    'URN:NBN:no-nb_digibok_2009031600127',
#    'URN:NBN:no-nb_digibok_2008081500025']),
#  '788c0345d7622ff5b8de8eee60ae08c304a6d70204ef6f9ec119e413bd309ad8': (['URN:NBN:no-nb_digibok_2010090320026',
#    'URN:NBN:no-nb_digibok_2011072012004',
#    'URN:NBN:no-nb_digibok_2014080424009',
#    'URN:NBN:no-nb_digibok_2010061720009',
#    'URN:NBN:no-nb_digibok_2010052820003'],
#   ['URN:NBN:no-nb_digibok_2010081720016',
#    'URN:NBN:no-nb_digibok_2010081920021',
#    'URN:NBN:no-nb_digibok_2009031600032',
#    'URN:NBN:no-nb_digibok_2011063022001',
#    'URN:NBN:no-nb_digibok_2012072708064',
#    'URN:NBN:no-nb_digibok_2010061412002',
#    'URN:NBN:no-nb_digibok_2010060820009',
#    'URN:NBN:no-nb_digibok_2009042203004',
#    'URN:NBN:no-nb_digibok_2008021104045',
#    'URN:NBN:no-nb_digibok_2010051812001']),
#  'e883f4ae1a7d9e01c13a536405542e2295830c3065fbd263bff432a84477e505': (['URN:NBN:no-nb_digibok_2010061720010',
#    'URN:NBN:no-nb_digibok_2013050224047'],
#    'URN:NBN:no-nb_digibok_2007122100036',
#    'URN:NBN:no-nb_digibok_2006111400028',
#    'URN:NBN:no-nb_digibok_2014092608039',
#    'URN:NBN:no-nb_digibok_2009072812001',
#    'URN:NBN:no-nb_digibok_2008040104103',
#    'URN:NBN:no-nb_digibok_2009072412002'],
#   ['URN:NBN:no-nb_digibok_2006083100087',
#    'URN:NBN:no-nb_digibok_2015091506126']),
#  '5f966dca3672b0948f66c148a8259562bb33807cb467ce14e86cdb08d206812a': (['URN:NBN:no-nb_digibok_2010111506037',
#    'URN:NBN:no-nb_digibok_2009072212001',
#    'URN:NBN:no-nb_digibok_2014111008005',
#    'URN:NBN:no-nb_digibok_2014092608039',
#    'URN:NBN:no-nb_digibok_2009072912001',
#    'URN:NBN:no-nb_digibok_2009072812002',
#    'URN:NBN:no-nb_digibok_2009071712001',
#    'URN:NBN:no-nb_digibok_2013042508156',
#    'URN:NBN:no-nb_digibok_2009072112001',
#    'URN:NBN:no-nb_digibok_2011032520038'],
#   ['URN:NBN:no-nb_digibok_2010102906097',
#    'URN:NBN:no-nb_digibok_2012112206221',
#    'URN:NBN:no-nb_digibok_2014092308143',
#    'URN:NBN:no-nb_digibok_2008022001004',
#    'URN:NBN:no-nb_digibok_2008070700052',
#    'URN:NBN:no-nb_digibok_2011070620007',
#    'URN:NBN:no-nb_digibok_2006083100087',
#    'URN:NBN:no-nb_digibok_2014073108005']),
#  '2c1889bffec1a5c9dddc3550b14693120473d2b8002d506222d341919ba4c406': (['URN:NBN:no-nb_digibok_2007050812003'],
#   ['URN:NBN:no-nb_digibok_2008022504059',
#    'URN:NBN:no-nb_digibok_2008022000047']),
#  '34e7e5e4fdd73901fc0ff6b359b53e4042da8bf5aeafee4ae638d497c6fac55b': (['URN:NBN:no-nb_digibok_2010030303003',
#    'URN:NBN:no-nb_digibok_2008050604010',
#    'URN:NBN:no-nb_digibok_2009032500001',
#    'URN:NBN:no-nb_digibok_2015051929001'],
#   ['URN:NBN:no-nb_digibok_2009011604050',
#    'URN:NBN:no-nb_digibok_2014032506066',
#    'URN:NBN:no-nb_digibok_2010080620001',
#    'URN:NBN:no-nb_digibok_2008101004078',
#    'URN:NBN:no-nb_digibok_2008071000094',
#    'URN:NBN:no-nb_digibok_2011102508116',
#    'URN:NBN:no-nb_digibok_2009031900017',
#    'URN:NBN:no-nb_digibok_2011011706058']),
#  'eae961d0a8c1ea07631e6083094d06c2ce7710fa68a086c4e5a68ea030f5e7f0': (['URN:NBN:no-nb_digibok_2011111108031'],
#   ['URN:NBN:no-nb_digibok_2012052925019',
#    'URN:NBN:no-nb_digibok_2013012108010',
#    'URN:NBN:no-nb_digibok_2013030608008',
#    'URN:NBN:no-nb_digibok_2013041605103',
#    'URN:NBN:no-nb_digibok_2007062210016',
#    'URN:NBN:no-nb_digibok_2009030900157',
#    'URN:NBN:no-nb_digibok_2010111208120',
#    'URN:NBN:no-nb_digibok_2007051604069',
#    'URN:NBN:no-nb_digibok_2009010704135',
#    'URN:NBN:no-nb_digibok_2008051504040',
#    'URN:NBN:no-nb_digibok_2014052308179',
#    'URN:NBN:no-nb_digibok_2011011706058',
#    'URN:NBN:no-nb_digibok_2008060301017',
#    'URN:NBN:no-nb_digibok_2008091701033',
#    'URN:NBN:no-nb_digibok_2008021104026',
#    'URN:NBN:no-nb_digibok_2008031000033',
#    'URN:NBN:no-nb_digibok_2009050610002',
#    'URN:NBN:no-nb_digibok_2013120238049',
#    'URN:NBN:no-nb_digibok_2008091104040',
#    'URN:NBN:no-nb_digibok_2009030300045']),
#  '0c4986de249cfcc2e713b0612a02de379b3139d45622cb92207d3812418b8785': (['URN:NBN:no-nb_digibok_2011011005074',
#    'URN:NBN:no-nb_digibok_2009051513002'],
#   ['URN:NBN:no-nb_digibok_2008101704023']),
#  'a0b80371be1e1051d9835338f84d5730b96737d8bcf8547d306c8669ed241e10': (['URN:NBN:no-nb_digibok_2009051203007',
#    'URN:NBN:no-nb_digibok_2008081300059',
#    'URN:NBN:no-nb_digibok_2008061900070',
#    'URN:NBN:no-nb_digibok_2014031008041',
#    'URN:NBN:no-nb_digibok_2011070620005'],
#   ['URN:NBN:no-nb_digibok_2010032213003',
#    'URN:NBN:no-nb_digibok_2015072108244',
#    'URN:NBN:no-nb_digibok_2009022400121']),
#  'f8d841475cf0188f72aa636dfba00930a976996c673cb865c052d15bdcc5a947': (['URN:NBN:no-nb_digibok_2008061900070',
#    'URN:NBN:no-nb_digibok_2011070620005'],
#   ['URN:NBN:no-nb_digibok_2009022400121']),
#  '6e87651444dfaffe843e5b0fa299f2ace9438ff2f40ab467e7b0cc4ce1aed4da': (['URN:NBN:no-nb_digibok_2012110706097',
#    'URN:NBN:no-nb_digibok_2008081200108',
#    'URN:NBN:no-nb_digibok_2008041804090'],
#   ['URN:NBN:no-nb_digibok_2012091908076',
#    'URN:NBN:no-nb_digibok_2009092912001',
#    'URN:NBN:no-nb_digibok_2008102901005']),
#  '1e1e560811ecf392262f3d2197f229bc2b8e468f97e294f708197beab42e2961': (['URN:NBN:no-nb_digibok_2012110706097',
#    'URN:NBN:no-nb_digibok_2008041804090',
#    'URN:NBN:no-nb_digibok_2008081200108'],
#   ['URN:NBN:no-nb_digibok_2012091908076',
#    'URN:NBN:no-nb_digibok_2008100100006',
#    'URN:NBN:no-nb_digibok_2008102901005']),
#  '3920d00a855a2c1304ff34f42d8a5f34b3b85ad13e272a3b5b20e313b75a0575': (['URN:NBN:no-nb_digibok_2009021100079',
#    'URN:NBN:no-nb_digibok_2008081200108',
#    'URN:NBN:no-nb_digibok_2008041804071',
#    'URN:NBN:no-nb_digibok_2009100512001',
#    'URN:NBN:no-nb_digibok_2009042000123',
#    'URN:NBN:no-nb_digibok_2012110706098'],
#   ['URN:NBN:no-nb_digibok_2008042201024',
#    'URN:NBN:no-nb_digibok_2013082806134',
#    'URN:NBN:no-nb_digibok_2009092912002']),
#  'cbac99d47f2054abbce8ba99bcf3b91dafd5c9ae1dd17bb9031f3360be04320d': (['URN:NBN:no-nb_digibok_2012110706098',
#    'URN:NBN:no-nb_digibok_2009042000123',
#    'URN:NBN:no-nb_digibok_2009091610001',
#    'URN:NBN:no-nb_digibok_2009010803011',
#    'URN:NBN:no-nb_digibok_2008081200108'],
#   ['URN:NBN:no-nb_digibok_2013082806134',
#    'URN:NBN:no-nb_digibok_2008042201024'])}

# %%
with open(os.path.join("parallellkorpus", "ny_gammel_versjon3.json"), "w") as f:
    json.dump(triple, f)

# %%
old_urns = [x for y in triple for x in triple[y][0]]
new_urns = [x for y in triple for x in triple[y][1]]

# %%
old = dh.CorpusFromIdentifiers(old_urns).corpus["authors title year langs urn".split()]
new = dh.CorpusFromIdentifiers(new_urns).corpus["authors title year langs urn".split()]
old['time'] = 'old'
new['time'] = 'new'
triple_corpus = pd.concat([old, new])

# %%
triple_corpus.sort_values(by='year').style
# Out:
# <style type="text/css">
# </style>
# <table id="T_1b7ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b7ca_level0_col0" class="col_heading level0 col0" >authors</th>
#       <th id="T_1b7ca_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_1b7ca_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_1b7ca_level0_col3" class="col_heading level0 col3" >langs</th>
#       <th id="T_1b7ca_level0_col4" class="col_heading level0 col4" >urn</th>
#       <th id="T_1b7ca_level0_col5" class="col_heading level0 col5" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b7ca_level0_row0" class="row_heading level0 row0" >94</th>
#       <td id="T_1b7ca_row0_col0" class="data row0 col0" >Collett , Camilla</td>
#       <td id="T_1b7ca_row0_col1" class="data row0 col1" >Amtmandens Døttre : en Fortælling. D. 1</td>
#       <td id="T_1b7ca_row0_col2" class="data row0 col2" >1855</td>
#       <td id="T_1b7ca_row0_col3" class="data row0 col3" >nob</td>
#       <td id="T_1b7ca_row0_col4" class="data row0 col4" >URN:NBN:no-nb_digibok_2011032520038</td>
#       <td id="T_1b7ca_row0_col5" class="data row0 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_1b7ca_row1_col0" class="data row1 col0" >Bjørnson , Bjørnstjerne / Dybwad , Jacob</td>
#       <td id="T_1b7ca_row1_col1" class="data row1 col1" >Mellem Slagene : Drama i 1 Akt</td>
#       <td id="T_1b7ca_row1_col2" class="data row1 col2" >1858</td>
#       <td id="T_1b7ca_row1_col3" class="data row1 col3" >nob</td>
#       <td id="T_1b7ca_row1_col4" class="data row1 col4" >URN:NBN:no-nb_digibok_2008070812004</td>
#       <td id="T_1b7ca_row1_col5" class="data row1 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row2" class="row_heading level0 row2" >93</th>
#       <td id="T_1b7ca_row2_col0" class="data row2 col0" >Collett , Camilla</td>
#       <td id="T_1b7ca_row2_col1" class="data row2 col1" >Amtmandens Døttre : en Fortælling</td>
#       <td id="T_1b7ca_row2_col2" class="data row2 col2" >1860</td>
#       <td id="T_1b7ca_row2_col3" class="data row2 col3" >nob</td>
#       <td id="T_1b7ca_row2_col4" class="data row2 col4" >URN:NBN:no-nb_digibok_2009072112001</td>
#       <td id="T_1b7ca_row2_col5" class="data row2 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row3" class="row_heading level0 row3" >80</th>
#       <td id="T_1b7ca_row3_col0" class="data row3 col0" >Collett , Camilla</td>
#       <td id="T_1b7ca_row3_col1" class="data row3 col1" >I de lange Nætter</td>
#       <td id="T_1b7ca_row3_col2" class="data row3 col2" >1863</td>
#       <td id="T_1b7ca_row3_col3" class="data row3 col3" >nob</td>
#       <td id="T_1b7ca_row3_col4" class="data row3 col4" >URN:NBN:no-nb_digibok_2006111400028</td>
#       <td id="T_1b7ca_row3_col5" class="data row3 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row4" class="row_heading level0 row4" >86</th>
#       <td id="T_1b7ca_row4_col0" class="data row4 col0" >Collett , Camilla</td>
#       <td id="T_1b7ca_row4_col1" class="data row4 col1" >Amtmannens döttrar : en norsk berättelse</td>
#       <td id="T_1b7ca_row4_col2" class="data row4 col2" >1863</td>
#       <td id="T_1b7ca_row4_col3" class="data row4 col3" >swe / nob</td>
#       <td id="T_1b7ca_row4_col4" class="data row4 col4" >URN:NBN:no-nb_digibok_2009072212001</td>
#       <td id="T_1b7ca_row4_col5" class="data row4 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row5" class="row_heading level0 row5" >82</th>
#       <td id="T_1b7ca_row5_col0" class="data row5 col0" >Collett , Camilla</td>
#       <td id="T_1b7ca_row5_col1" class="data row5 col1" >Under långa nätter</td>
#       <td id="T_1b7ca_row5_col2" class="data row5 col2" >1866</td>
#       <td id="T_1b7ca_row5_col3" class="data row5 col3" >swe / nob</td>
#       <td id="T_1b7ca_row5_col4" class="data row5 col4" >URN:NBN:no-nb_digibok_2009072812001</td>
#       <td id="T_1b7ca_row5_col5" class="data row5 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row6" class="row_heading level0 row6" >16</th>
#       <td id="T_1b7ca_row6_col0" class="data row6 col0" >Ibsen , Henrik</td>
#       <td id="T_1b7ca_row6_col1" class="data row6 col1" >Brand : et dramatisk Digt</td>
#       <td id="T_1b7ca_row6_col2" class="data row6 col2" >1866</td>
#       <td id="T_1b7ca_row6_col3" class="data row6 col3" >nob</td>
#       <td id="T_1b7ca_row6_col4" class="data row6 col4" >URN:NBN:no-nb_digibok_2014080424009</td>
#       <td id="T_1b7ca_row6_col5" class="data row6 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row7" class="row_heading level0 row7" >20</th>
#       <td id="T_1b7ca_row7_col0" class="data row7 col0" >Ibsen , Henrik</td>
#       <td id="T_1b7ca_row7_col1" class="data row7 col1" >De Unges Forbund : Lystspil i fem Akter</td>
#       <td id="T_1b7ca_row7_col2" class="data row7 col2" >1869</td>
#       <td id="T_1b7ca_row7_col3" class="data row7 col3" >nob</td>
#       <td id="T_1b7ca_row7_col4" class="data row7 col4" >URN:NBN:no-nb_digibok_2013050224047</td>
#       <td id="T_1b7ca_row7_col5" class="data row7 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row8" class="row_heading level0 row8" >158</th>
#       <td id="T_1b7ca_row8_col0" class="data row8 col0" >Lie , Jonas</td>
#       <td id="T_1b7ca_row8_col1" class="data row8 col1" >Den Fremsynte, eller Billeder fra Nordland</td>
#       <td id="T_1b7ca_row8_col2" class="data row8 col2" >1870</td>
#       <td id="T_1b7ca_row8_col3" class="data row8 col3" >nob</td>
#       <td id="T_1b7ca_row8_col4" class="data row8 col4" >URN:NBN:no-nb_digibok_2012060106021</td>
#       <td id="T_1b7ca_row8_col5" class="data row8 col5" >new</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row9" class="row_heading level0 row9" >66</th>
#       <td id="T_1b7ca_row9_col0" class="data row9 col0" >Lie , Jonas</td>
#       <td id="T_1b7ca_row9_col1" class="data row9 col1" >Den Fremsynte, eller Billeder fra Nordland</td>
#       <td id="T_1b7ca_row9_col2" class="data row9 col2" >1873</td>
#       <td id="T_1b7ca_row9_col3" class="data row9 col3" >nob</td>
#       <td id="T_1b7ca_row9_col4" class="data row9 col4" >URN:NBN:no-nb_digibok_2010052806015</td>
#       <td id="T_1b7ca_row9_col5" class="data row9 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row10" class="row_heading level0 row10" >73</th>
#       <td id="T_1b7ca_row10_col0" class="data row10 col0" >Ibsen , Henrik</td>
#       <td id="T_1b7ca_row10_col1" class="data row10 col1" >Kejser og Galilæer : et verdenshistorisk skuespil</td>
#       <td id="T_1b7ca_row10_col2" class="data row10 col2" >1873</td>
#       <td id="T_1b7ca_row10_col3" class="data row10 col3" >nob</td>
#       <td id="T_1b7ca_row10_col4" class="data row10 col4" >URN:NBN:no-nb_digibok_2013050224106</td>
#       <td id="T_1b7ca_row10_col5" class="data row10 col5" >new</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row11" class="row_heading level0 row11" >5</th>
#       <td id="T_1b7ca_row11_col0" class="data row11 col0" >Bjørnson , Bjørnstjerne</td>
#       <td id="T_1b7ca_row11_col1" class="data row11 col1" >Brude-Slaatten</td>
#       <td id="T_1b7ca_row11_col2" class="data row11 col2" >1873</td>
#       <td id="T_1b7ca_row11_col3" class="data row11 col3" >nob</td>
#       <td id="T_1b7ca_row11_col4" class="data row11 col4" >URN:NBN:no-nb_digibok_2008071812003</td>
#       <td id="T_1b7ca_row11_col5" class="data row11 col5" >old</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ca_level0_row12" class="row_heading level0 row12" >55</th>
#       <td id="T_1b7ca_row12_col0" class="data row12 col0" >Ibsen , Henrik / Dass , Petter / Johnston , Andrew</td>
#       <td id="T_1b7ca_row12_col1" class="data row12 col1" >Translations from the Norse</td>
#       <td id="T_1b7ca_row12_col2" class="data row12 col2" >1877</td>
#       <td id="T_1b7ca_row12_col3" class="data row12 col3" >eng / nob</td>
#       <td id="T_1b7ca_row12_col4" class="data row12 col4" >URN:NBN:no-nb_digibok_2011012
