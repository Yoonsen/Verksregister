# %% [markdown]
# # Create and evaluate a corpus of books
#
# The corpus is taken from the works-registry, and the evaluation selects books that belong to different epochs, where each epoch is defined by the variable `matrix`. This variable contains a dataframe with columns corresponding to epochs and rows are words with different weights within the epoch.

# %%
import dhlab.module_update as mu
import dhlab.text as dh
import pandas as pd
import verk as v
import evaluate_corpus as ev
import json
import os

# %%
mu.css()
# Out:
# <style>@import url(http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# p {
#     font-size:1.3em;
#     font-family:serif;
#     line-height:1.4em;
#     color:#142850;
# }
# h1, h2, h3, h4 {
#     color:#27496d;
# }
#
# /*
# .prompt, .jp-InputPrompt, .jp-InputArea-prompt, .jp-OutputPrompt, .jp-OutputArea-prompt {
#     visibility: hidden;
# }
#
#
# .jp-CodeCell .jp-Notebook-cell    {
#     margin-left:10%;
#     margin-right:5%;
# }
#
#
# .jp-InputArea, .jp-OutputArea {
#     margin-left:2.5em;
#     margin-right:2.5em;
# }
# */
#
#
# body  {
#     margin:10%;
#     counter-reset: h1counter;
#
# }
#
# /* .jp-MarkdownOutput, .text_cell_render {
#
#     background-color:#FEFBF1;
#     border-style: solid;
#     border-width: 1px;
#     border-color: rgba(0,0,0, 0.10);;
# } */
#
#
# h1:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 50%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:3px solid SlateGray; /* FireBrick; */
# }
#
# h2:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 30%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:2px solid SlateGray; /* FireBrick; */
# }
#
# </style>

# %% [markdown]
# The process is this
#
# 1. Create a matrix
# 2. Find works
# 3. Evaluate the works against the matrix
# 4. Create a parallell corpus from the evaluation

# %%
matrix = pd.read_csv("old_vs_new_word_list.csv", index_col = 0)

# %% [markdown]
# Create a list of books from know authors or books. This can be done by an exhaustive search or by more contentrated search.

# %%
authors = ["bjørnstjerne bjørnson",  "cora sandel", "goethe", "nietsche", "henrik ibsen", "amalie skram", "alexander kielland", "jonas lie", "camilla collett"]

# %%
authors = [  "sigrid undset", "knut hamsun", "Per Christen Asbjørnsen","Arne Garborg ", "hulda garborg","Henrik Wergeland", "Sigbjørn Obstfelder" ]

# %%
author_corpus = {
    auth: dh.Corpus(doctype="digibok", author= auth, limit = 1000, to_year = 1920) for auth in authors
}

# %% [markdown]
# Here is what the `author_corpus` looks like

# %% [markdown]
# Find the works identifiers, here stored in the variable `works`, from the list of authors, and then looping through the titles.

# %%
works = []
for a in author_corpus: 
    for t in author_corpus[a].corpus.title:
        try:
            works.extend(v.find_works(a, t)['id'].values)
        except:
            pass

# %% [markdown]
# From this list of different works a parallell corpus is created, using the matrix to find modernized versions.

# %%
import importlib
importlib.reload(v)
importlib.reload(ev)
# Out:
# <module 'evaluate_corpus' from '/mnt/disk1/Github/Verksregister/evaluate_corpus.py'>

# %% [markdown]
# Go through the works list and see if there are URNs in the list. Keep those works with more than one URN

# %%
len(works)
# Out:
# 157

# %%
parallel_candidates = {works_id: v.urns_for_works(works_id) for works_id in works}

# %%
candidates = {x:parallel_candidates[x] for x in parallel_candidates if len(parallel_candidates[x]) > 1}

# %%
candidates[list(candidates.keys())[3]]
# Out:
# ['URN:NBN:no-nb_digibok_2007051012004', 'URN:NBN:no-nb_digibok_2008061704148']

# %%
import importlib
importlib.reload(ev)
# Out:
# <module 'evaluate_corpus' from '/mnt/disk1/Github/Verksregister/evaluate_corpus.py'>

# %%
c = dh.CorpusFromIdentifiers(candidates[list(candidates.keys())[2]])

# %%
c.corpus
# Out:
#      dhlabid                                        title          authors  \
# 0  100505639          Fortællingen om Viga-Ljot og Vigdis  Undset , Sigrid
# 1  100478661  Fortellingen om Viga-Ljot og Vigdis : roman  Undset , Sigrid
# 2  100534160          Fortellingen om Viga-Ljot og Vigdis  Undset , Sigrid
#
#                                    urn                                oaiid  \
# 0  URN:NBN:no-nb_digibok_2007050812003  oai:nb.bibsys.no:999110884824702202
# 1  URN:NBN:no-nb_digibok_2008022000047  oai:nb.bibsys.no:999502068574702202
# 2  URN:NBN:no-nb_digibok_2008022504059  oai:nb.bibsys.no:999522347184702202
#
#                             sesamid      isbn10        city  timestamp  year  \
# 0  bc57ad39def59311af88a6bdae325f47              Kristiania   19090101  1909
# 1  28cd3ef4a99a64e480ea89d3a4f63757  8203172210        Oslo   19950101  1995
# 2  ffbd0fc88fb6c6e1dd6b83c6cb892066  8252529267      [Oslo]   19950101  1995
#
#                publisher langs   subjects      ddc   genres      literaryform  \
# 0              Aschehoug   nob                                  Uklassifisert
# 1              Aschehoug   nob  historisk  839.823  fiction  Skjønnlitteratur
# 2  Den norske bokklubben   nob             839.823  fiction  Skjønnlitteratur
#
#    doctype
# 0  digibok
# 1  digibok
# 2  digibok

# %%
ev.evaluate_corpus_norwegian(corpus = c, matrix=matrix, top_number = 10)
# Out:
# {'URN:NBN:no-nb_digibok_2008022504059': ('1990', 0.14467340770330372),
#  'URN:NBN:no-nb_digibok_2008022000047': ('1990', 0.15744813501148414),
#  'URN:NBN:no-nb_digibok_2007050812003': ('1920', 0.17941035464430233)}

# %%
evals = {}
for worksid in candidates:
    try:
        evals[worksid] = ev.evaluate_corpus_norwegian(corpus = dh.CorpusFromIdentifiers(candidates[worksid]), matrix = matrix)
    except KeyboardInterrupt:
        break
    except:
        pass

# %%
triple = {}
for i in evals:
    data = evals[i]
    old = [x for x in data if int(data[x][0]) <= 1900 ]
    new = [x for x in data if int(data[x][0]) > 1900 ] 
    if old != [] and new != []:
        triple[i] = (old, new)

# %%
triple
# Out:
# {'2c1889bffec1a5c9dddc3550b14693120473d2b8002d506222d341919ba4c406': (['URN:NBN:no-nb_digibok_2007050812003'],
#   ['URN:NBN:no-nb_digibok_2008022504059',
#    'URN:NBN:no-nb_digibok_2008022000047']),
#  '0c4986de249cfcc2e713b0612a02de379b3139d45622cb92207d3812418b8785': (['URN:NBN:no-nb_digibok_2009051513002',
#    'URN:NBN:no-nb_digibok_2011011005074'],
#   ['URN:NBN:no-nb_digibok_2008101704023']),
#  '34e7e5e4fdd73901fc0ff6b359b53e4042da8bf5aeafee4ae638d497c6fac55b': (['URN:NBN:no-nb_digibok_2008050604010',
#    'URN:NBN:no-nb_digibok_2009032500001',
#    'URN:NBN:no-nb_digibok_2015051929001',
#    'URN:NBN:no-nb_digibok_2010030303003'],
#   ['URN:NBN:no-nb_digibok_2011102508116',
#    'URN:NBN:no-nb_digibok_2011011706058',
#    'URN:NBN:no-nb_digibok_2009031900017',
#    'URN:NBN:no-nb_digibok_2009011604050',
#    'URN:NBN:no-nb_digibok_2014032506066',
#    'URN:NBN:no-nb_digibok_2010080620001',
#    'URN:NBN:no-nb_digibok_2008101004078',
#    'URN:NBN:no-nb_digibok_2008071000094']),
#  'eae961d0a8c1ea07631e6083094d06c2ce7710fa68a086c4e5a68ea030f5e7f0': (['URN:NBN:no-nb_digibok_2011111108031'],
#   ['URN:NBN:no-nb_digibok_2010111208120',
#    'URN:NBN:no-nb_digibok_2007051604069',
#    'URN:NBN:no-nb_digibok_2007062210016',
#    'URN:NBN:no-nb_digibok_2009030900157',
#    'URN:NBN:no-nb_digibok_2008031000033',
#    'URN:NBN:no-nb_digibok_2008021104026',
#    'URN:NBN:no-nb_digibok_2008091701033',
#    'URN:NBN:no-nb_digibok_2008060301017',
#    'URN:NBN:no-nb_digibok_2011011706058',
#    'URN:NBN:no-nb_digibok_2013030608008',
#    'URN:NBN:no-nb_digibok_2013041605103',
#    'URN:NBN:no-nb_digibok_2008091104040',
#    'URN:NBN:no-nb_digibok_2012052925019',
#    'URN:NBN:no-nb_digibok_2013012108010',
#    'URN:NBN:no-nb_digibok_2009010704135',
#    'URN:NBN:no-nb_digibok_2008051504040',
#    'URN:NBN:no-nb_digibok_2009050610002',
#    'URN:NBN:no-nb_digibok_2009030300045',
#    'URN:NBN:no-nb_digibok_2014052308179',
#    'URN:NBN:no-nb_digibok_2013120238049']),
#  'e03af65a6f28cd54ceedd5acc2bc1d4904889fa9ca0f6f12f98d76fbd0eef0d7': (['URN:NBN:no-nb_digibok_2011011005061'],
#   ['URN:NBN:no-nb_digibok_2010042603024',
#    'URN:NBN:no-nb_digibok_2008091603013',
#    'URN:NBN:no-nb_digibok_2008091603017',
#    'URN:NBN:no-nb_digibok_2008102204060',
#    'URN:NBN:no-nb_digibok_2008121712001']),
#  'f8d841475cf0188f72aa636dfba00930a976996c673cb865c052d15bdcc5a947': (['URN:NBN:no-nb_digibok_2011070620005',
#    'URN:NBN:no-nb_digibok_2008061900070'],
#   ['URN:NBN:no-nb_digibok_2009022400121']),
#  'a0b80371be1e1051d9835338f84d5730b96737d8bcf8547d306c8669ed241e10': (['URN:NBN:no-nb_digibok_2008081300059',
#    'URN:NBN:no-nb_digibok_2011070620005',
#    'URN:NBN:no-nb_digibok_2008061900070',
#    'URN:NBN:no-nb_digibok_2014031008041',
#    'URN:NBN:no-nb_digibok_2009051203007'],
#   ['URN:NBN:no-nb_digibok_2009022400121',
#    'URN:NBN:no-nb_digibok_2015072108244',
#    'URN:NBN:no-nb_digibok_2010032213003']),
#  '2006d57396cba2e8425485847e788d67800df61ec2363cc2e748895ae80b15b4': (['URN:NBN:no-nb_digibok_2008061900070',
#    'URN:NBN:no-nb_digibok_2012051408100',
#    'URN:NBN:no-nb_digibok_2011070620005'],
#   ['URN:NBN:no-nb_digibok_2009022400121',
#    'URN:NBN:no-nb_digibok_2010032213003',
#    'URN:NBN:no-nb_digibok_2015072108244',
#    'URN:NBN:no-nb_digibok_2011080406126']),
#  'ebf40b84594edffbd7a785cd23eecb38b9873aa2018036f9828eabea94637ff9': (['URN:NBN:no-nb_digibok_2008041804090',
#    'URN:NBN:no-nb_digibok_2012110706097',
#    'URN:NBN:no-nb_digibok_2012092608177'],
#   ['URN:NBN:no-nb_digibok_2012091908076',
#    'URN:NBN:no-nb_digibok_2008102901005']),
#  'b48c3f45bf88583d3001cc265b99408424183688ff864096ea8498617c104b91': (['URN:NBN:no-nb_digibok_2009021100079',
#    'URN:NBN:no-nb_digibok_2009042000123'],
#   ['URN:NBN:no-nb_digibok_2009111012005']),
#  '1e1e560811ecf392262f3d2197f229bc2b8e468f97e294f708197beab42e2961': (['URN:NBN:no-nb_digibok_2008041804090',
#    'URN:NBN:no-nb_digibok_2012110706097',
#    'URN:NBN:no-nb_digibok_2008081200108'],
#   ['URN:NBN:no-nb_digibok_2012091908076',
#    'URN:NBN:no-nb_digibok_2008100100006',
#    'URN:NBN:no-nb_digibok_2008102901005']),
#  '6e87651444dfaffe843e5b0fa299f2ace9438ff2f40ab467e7b0cc4ce1aed4da': (['URN:NBN:no-nb_digibok_2012110706097',
#    'URN:NBN:no-nb_digibok_2008041804090',
#    'URN:NBN:no-nb_digibok_2008081200108'],
#   ['URN:NBN:no-nb_digibok_2009092912001',
#    'URN:NBN:no-nb_digibok_2012091908076',
#    'URN:NBN:no-nb_digibok_2008102901005']),
#  '3920d00a855a2c1304ff34f42d8a5f34b3b85ad13e272a3b5b20e313b75a0575': (['URN:NBN:no-nb_digibok_2009042000123',
#    'URN:NBN:no-nb_digibok_2012110706098',
#    'URN:NBN:no-nb_digibok_2008041804071',
#    'URN:NBN:no-nb_digibok_2008081200108',
#    'URN:NBN:no-nb_digibok_2009021100079',
#    'URN:NBN:no-nb_digibok_2009100512001'],
#   ['URN:NBN:no-nb_digibok_2013082806134',
#    'URN:NBN:no-nb_digibok_2009092912002',
#    'URN:NBN:no-nb_digibok_2008042201024']),
#  'cbac99d47f2054abbce8ba99bcf3b91dafd5c9ae1dd17bb9031f3360be04320d': (['URN:NBN:no-nb_digibok_2009091610001',
#    'URN:NBN:no-nb_digibok_2009010803011',
#    'URN:NBN:no-nb_digibok_2008081200108',
#    'URN:NBN:no-nb_digibok_2012110706098',
#    'URN:NBN:no-nb_digibok_2009042000123'],
#   ['URN:NBN:no-nb_digibok_2008042201024',
#    'URN:NBN:no-nb_digibok_2013082806134'])}

# %%
with open(os.path.join("parallellkorpus", "ny_gammel_versjon2.json"), "w") as f:
    json.dump(triple, f)

# %%
dh.CorpusFromIdentifiers([x for y in triple.values() for z in y for x in z]).corpus["authors title year langs".split()].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_83b1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83b1c_level0_col0" class="col_heading level0 col0" >authors</th>
#       <th id="T_83b1c_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_83b1c_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_83b1c_level0_col3" class="col_heading level0 col3" >langs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83b1c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83b1c_row0_col0" class="data row0 col0" >Undset , Sigrid</td>
#       <td id="T_83b1c_row0_col1" class="data row0 col1" >Fortællingen om Viga-Ljot og Vigdis</td>
#       <td id="T_83b1c_row0_col2" class="data row0 col2" >1909</td>
#       <td id="T_83b1c_row0_col3" class="data row0 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83b1c_row1_col0" class="data row1 col0" >Undset , Sigrid</td>
#       <td id="T_83b1c_row1_col1" class="data row1 col1" >Fortellingen om Viga-Ljot og Vigdis</td>
#       <td id="T_83b1c_row1_col2" class="data row1 col2" >1995</td>
#       <td id="T_83b1c_row1_col3" class="data row1 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83b1c_row2_col0" class="data row2 col0" >Undset , Sigrid</td>
#       <td id="T_83b1c_row2_col1" class="data row2 col1" >Fortellingen om Viga-Ljot og Vigdis : roman</td>
#       <td id="T_83b1c_row2_col2" class="data row2 col2" >1995</td>
#       <td id="T_83b1c_row2_col3" class="data row2 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83b1c_row3_col0" class="data row3 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row3_col1" class="data row3 col1" >Livets Spil</td>
#       <td id="T_83b1c_row3_col2" class="data row3 col2" >1896</td>
#       <td id="T_83b1c_row3_col3" class="data row3 col3" >mul / dan / nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83b1c_row4_col0" class="data row4 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row4_col1" class="data row4 col1" >Samlede Verker. 6 : Ved Rikets Port ; Livets Spil ; Aftenrøde ; Livet i Vold</td>
#       <td id="T_83b1c_row4_col2" class="data row4 col2" >1934</td>
#       <td id="T_83b1c_row4_col3" class="data row4 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83b1c_row5_col0" class="data row5 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row5_col1" class="data row5 col1" >Samlede verker. B. 14 : Ved rikets port ; Livets spil ; Aftenrøde ; Munken Vendt</td>
#       <td id="T_83b1c_row5_col2" class="data row5 col2" >2000</td>
#       <td id="T_83b1c_row5_col3" class="data row5 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83b1c_row6_col0" class="data row6 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row6_col1" class="data row6 col1" >Sult : roman</td>
#       <td id="T_83b1c_row6_col2" class="data row6 col2" >1953</td>
#       <td id="T_83b1c_row6_col3" class="data row6 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_83b1c_row7_col0" class="data row7 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row7_col1" class="data row7 col1" >Sult</td>
#       <td id="T_83b1c_row7_col2" class="data row7 col2" >1990</td>
#       <td id="T_83b1c_row7_col3" class="data row7 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_83b1c_row8_col0" class="data row8 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row8_col1" class="data row8 col1" >Sult</td>
#       <td id="T_83b1c_row8_col2" class="data row8 col2" >1890</td>
#       <td id="T_83b1c_row8_col3" class="data row8 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_83b1c_row9_col0" class="data row9 col0" >Hamsun , Knut / Lyngstad , Sverre</td>
#       <td id="T_83b1c_row9_col1" class="data row9 col1" >Hunger</td>
#       <td id="T_83b1c_row9_col2" class="data row9 col2" >1996</td>
#       <td id="T_83b1c_row9_col3" class="data row9 col3" >eng / nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_83b1c_row10_col0" class="data row10 col0" >Hamsun , Knut / Eggen , Einar</td>
#       <td id="T_83b1c_row10_col1" class="data row10 col1" >Sult</td>
#       <td id="T_83b1c_row10_col2" class="data row10 col2" >1970</td>
#       <td id="T_83b1c_row10_col3" class="data row10 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_83b1c_row11_col0" class="data row11 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row11_col1" class="data row11 col1" >Samlede Verker. 1 : Sult ; Pan ; Victoria</td>
#       <td id="T_83b1c_row11_col2" class="data row11 col2" >1934</td>
#       <td id="T_83b1c_row11_col3" class="data row11 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_83b1c_row12_col0" class="data row12 col0" >Hamsun , Knut / Jenssen , Olav Christopher</td>
#       <td id="T_83b1c_row12_col1" class="data row12 col1" >Sult</td>
#       <td id="T_83b1c_row12_col2" class="data row12 col2" >1990</td>
#       <td id="T_83b1c_row12_col3" class="data row12 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_83b1c_row13_col0" class="data row13 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row13_col1" class="data row13 col1" >Sult</td>
#       <td id="T_83b1c_row13_col2" class="data row13 col2" >1998</td>
#       <td id="T_83b1c_row13_col3" class="data row13 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_83b1c_row14_col0" class="data row14 col0" >Hamsun , Knut / Rottem , Øystein</td>
#       <td id="T_83b1c_row14_col1" class="data row14 col1" >Sult</td>
#       <td id="T_83b1c_row14_col2" class="data row14 col2" >1989</td>
#       <td id="T_83b1c_row14_col3" class="data row14 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_83b1c_row15_col0" class="data row15 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row15_col1" class="data row15 col1" >Samlede verker. B. 1 : Sult ; Mysterier</td>
#       <td id="T_83b1c_row15_col2" class="data row15 col2" >1997</td>
#       <td id="T_83b1c_row15_col3" class="data row15 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_83b1c_row16_col0" class="data row16 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row16_col1" class="data row16 col1" >Samlede verker. B. 1 : Sult ; Mysterier</td>
#       <td id="T_83b1c_row16_col2" class="data row16 col2" >2000</td>
#       <td id="T_83b1c_row16_col3" class="data row16 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_83b1c_row17_col0" class="data row17 col0" >Hamsun , Knut / Gundersen , Dag / Kittelsen , Th. / Marstrander , Vilhelm / Sørensen , Hans Gerhard / Werenskiold , Erik</td>
#       <td id="T_83b1c_row17_col1" class="data row17 col1" >Sult</td>
#       <td id="T_83b1c_row17_col2" class="data row17 col2" >1996</td>
#       <td id="T_83b1c_row17_col3" class="data row17 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_83b1c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_83b1c_row18_col0" class="data row18 col0" >Hamsun , Knut</td>
#       <td id="T_83b1c_row18_col1"
