# %% [markdown]
# # Create and evaluate a corpus of books
#
# The corpus is taken from the works-registry, and the evaluation selects books that belong to different epochs, where each epoch is defined by the variable `matrix`. This variable contains a dataframe with columns corresponding to epochs and rows are words with different weights within the epoch.

# %%
import dhlab.module_update as mu
import dhlab.text as dh
import pandas as pd
import verk as v
import evaluate_corpus as ev
import json

# %%
mu.css()
# Out:
# <style>@import url(http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# p {
#     font-size:1.3em;
#     font-family:serif;
#     line-height:1.4em;
#     color:#142850;
# }
# h1, h2, h3, h4 {
#     color:#27496d;
# }
#
# /*
# .prompt, .jp-InputPrompt, .jp-InputArea-prompt, .jp-OutputPrompt, .jp-OutputArea-prompt {
#     visibility: hidden;
# }
#
#
# .jp-CodeCell .jp-Notebook-cell    {
#     margin-left:10%;
#     margin-right:5%;
# }
#
#
# .jp-InputArea, .jp-OutputArea {
#     margin-left:2.5em;
#     margin-right:2.5em;
# }
# */
#
#
# body  {
#     margin:10%;
#     counter-reset: h1counter;
#
# }
#
# /* .jp-MarkdownOutput, .text_cell_render {
#
#     background-color:#FEFBF1;
#     border-style: solid;
#     border-width: 1px;
#     border-color: rgba(0,0,0, 0.10);;
# } */
#
#
# h1:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 50%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:3px solid SlateGray; /* FireBrick; */
# }
#
# h2:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 30%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:2px solid SlateGray; /* FireBrick; */
# }
#
# </style>

# %%
matrix = pd.read_csv("old_vs_new_word_list.csv", index_col = 0)

# %% [markdown]
# The process is this
#
# 1. Create a matrix
# 2. Find works
# 3. Evaluate the works against the matrix
# 4. Create a parallell corpus from the evaluation

# %% [markdown]
# Create a list of books from know authors or books. This can be done by an exhaustive search or by more contentrated search.

# %%
authors = ["bjørnstjerne bjørnson",  "cora sandel", "goethe", "nietsche", "henrik ibsen", "amalie skram", "alexander kielland", "jonas lie", "camilla collett"]

# %% [markdown]
# authors = [ "cora sandel"]

# %%
author_corpus = {
    auth: dh.Corpus(doctype="digibok", author= auth, limit = 1000, to_year = 1920) for auth in authors
}

# %% [markdown]
# Here is what the `author_corpus` looks like

# %%
author_corpus[authors[0]].corpus[['urn', 'authors', 'year', 'title']].sample(5)
# Out:
#                                      urn  \
# 211  URN:NBN:no-nb_digibok_2011103124023
# 258  URN:NBN:no-nb_digibok_2014120308100
# 103  URN:NBN:no-nb_digibok_2008060613002
# 107  URN:NBN:no-nb_digibok_2008060613006
# 36   URN:NBN:no-nb_digibok_2016012129003
#
#                                                authors  year  \
# 211                            Bjørnson , Bjørnstjerne  1873
# 258  Bjørnson , Bjørnstjerne / Dietrichson , L. (Lo...  1907
# 103                            Bjørnson , Bjørnstjerne  1872
# 107                            Bjørnson , Bjørnstjerne  1872
# 36                             Bjørnson , Bjørnstjerne  1861
#
#                                                  title
# 211                                    Fortællinger. 1
# 258                                              Taler
# 103                                 Sangen har Lysning
# 107  Ved kirke-sanger A. Reitan's jordefærd den 4de...
# 36                                         Kong Sverre

# %% [markdown]
# Find the works identifiers, here stored in the variable `works`, from the list of authors, and then looping through the titles.

# %%
works = []
for a in author_corpus: 
    for t in author_corpus[a].corpus.title:
        try:
            works.extend(v.find_works(a, t)['id'].values)
        except:
            pass

# %% [markdown]
# From this list of different works a parallell corpus is created, using the matrix to find modernized versions.

# %%
import importlib
importlib.reload(v)
importlib.reload(ev)
# Out:
# <module 'evaluate_corpus' from '/mnt/disk1/Github/Historisk_ordbok/verksregister/evaluate_corpus.py'>

# %% [markdown]
# Go through the works list and see if there are URNs in the list. Keep those works with more than one URN

# %%
len(works)
# Out:
# 384

# %%
parallel_candidates = {works_id: v.urns_for_works(works_id) for works_id in works}

# %%
candidates = {x:parallel_candidates[x] for x in parallel_candidates if len(parallel_candidates[x]) > 1}

# %%
candidates[list(candidates.keys())[3]]
# Out:
# ['URN:NBN:no-nb_digibok_2012070905001',
#  'URN:NBN:no-nb_digibok_2011031012001',
#  'URN:NBN:no-nb_digibok_2012070408109',
#  'URN:NBN:no-nb_digibok_2010021803059',
#  'URN:NBN:no-nb_digibok_2006082900066',
#  'URN:NBN:no-nb_digibok_2008051504087',
#  'URN:NBN:no-nb_digibok_2009062204013',
#  'URN:NBN:no-nb_digibok_2006082400043',
#  'URN:NBN:no-nb_digibok_2008052204119',
#  'URN:NBN:no-nb_digibok_2008061900071',
#  'URN:NBN:no-nb_digibok_2010070106207',
#  'URN:NBN:no-nb_digibok_2010032213006']

# %%
import importlib
importlib.reload(ev)
# Out:
# <module 'evaluate_corpus' from '/home/yoonsen/Git/Historisk_ordbok/verksregister/evaluate_corpus.py'>

# %%
c = dh.CorpusFromIdentifiers(candidates[list(candidates.keys())[2]])

# %%
c.corpus
# Out:
#      dhlabid                            title  \
# 0  100017774  Jeg velger meg april! : 95 dikt
# 1  100523238  Jeg velger meg april! : 95 dikt
#
#                                      authors  \
# 0  Bjørnson , Bjørnstjerne / Jacobsen , Rolf
# 1  Bjørnson , Bjørnstjerne / Jacobsen , Rolf
#
#                                    urn                                oaiid  \
# 0  URN:NBN:no-nb_digibok_2009022600051  oai:nb.bibsys.no:990006123834702202
# 1  URN:NBN:no-nb_digibok_2008060904035  oai:nb.bibsys.no:998221829204702202
#
#                             sesamid                   isbn10    city  \
# 0  c4d8df04e679252120e9e17104be3460  8252536239 / 8205270953  [Oslo]
# 1  70edce0e4d9c819ac708e981510923ec               8205138958    Oslo
#
#    timestamp  year  publisher langs       subjects      ddc   genres  \
# 0   20000101  2000  Gyldendal   nob                 839.821  fiction
# 1   19820101  1982  Gyldendal   nob  norske / dikt   839.91  fiction
#
#        literaryform  doctype
# 0  Skjønnlitteratur  digibok
# 1  Skjønnlitteratur  digibok

# %%
ev.evaluate_corpus_norwegian(corpus = c, matrix=matrix, top_number = 10)
# Out:
# {'URN:NBN:no-nb_digibok_2008060904035': ('1800', 0.3838943153285951),
#  'URN:NBN:no-nb_digibok_2009022600051': ('1800', 0.38981935504134235)}

# %%
evals = {}
for worksid in candidates:
    try:
        evals[worksid] = ev.evaluate_corpus_norwegian(corpus = dh.CorpusFromIdentifiers(candidates[worksid]), matrix = matrix)
    except KeyboardInterrupt:
        break
    except:
        pass

# %%
triple = {}
for i in evals:
    data = evals[i]
    old = [x for x in data if int(data[x][0]) <= 1900 ]
    new = [x for x in data if int(data[x][0]) > 1900 ] 
    if old != [] and new != []:
        triple[i] = (old, new)

# %%
triple
# Out:
# {'eafd78267a468b309fb4eddc1cb3840479fcdad9089094b8ae075a1fc749242e': (['URN:NBN:no-nb_digibok_2008060904035',
#    'URN:NBN:no-nb_digibok_2009022600051'],
#   ['URN:NBN:no-nb_digibok_2008071812002']),
#  '4405c68f5bb3e077ec405b10d5c5df9ed097eb20adaddfdc052d1215a05b1c5c': (['URN:NBN:no-nb_digibok_2006080900015',
#    'URN:NBN:no-nb_digibok_2009062200004'],
#   ['URN:NBN:no-nb_digibok_2008070812004']),
#  '396ddc56ae4b19a533550b9d63df04bd9c25c8675ae3768ac9f1aead4f0e3b56': (['URN:NBN:no-nb_digibok_2008051504087',
#    'URN:NBN:no-nb_digibok_2011031012001',
#    'URN:NBN:no-nb_digibok_2006082400043',
#    'URN:NBN:no-nb_digibok_2010070106207',
#    'URN:NBN:no-nb_digibok_2006082900066',
#    'URN:NBN:no-nb_digibok_2010032213006',
#    'URN:NBN:no-nb_digibok_2008052204119',
#    'URN:NBN:no-nb_digibok_2009062204013',
#    'URN:NBN:no-nb_digibok_2012070905001',
#    'URN:NBN:no-nb_digibok_2008061900071'],
#   ['URN:NBN:no-nb_digibok_2010021803059',
#    'URN:NBN:no-nb_digibok_2012070408109']),
#  '262824678d4b0e2d8695df21b6d920c786cd5c019dcb82ad99b458b057e3d243': (['URN:NBN:no-nb_digibok_2008060904035',
#    'URN:NBN:no-nb_digibok_2009022600051'],
#   ['URN:NBN:no-nb_digibok_2012102107020']),
#  '1d4ea7e02197c411eb6670d943664e88beded896e11093af4063c9a5c13d7211': (['URN:NBN:no-nb_digibok_2011031012001',
#    'URN:NBN:no-nb_digibok_2008051504087',
#    'URN:NBN:no-nb_digibok_2010070106207',
#    'URN:NBN:no-nb_digibok_2006082400043',
#    'URN:NBN:no-nb_digibok_2008060904035',
#    'URN:NBN:no-nb_digibok_2012070905001',
#    'URN:NBN:no-nb_digibok_2008061900071',
#    'URN:NBN:no-nb_digibok_2009022600051',
#    'URN:NBN:no-nb_digibok_2010032213006'],
#   ['URN:NBN:no-nb_digibok_2012070408109']),
#  '50479b0cfbc89d081154db811ba107c616c1d20bf9e650b898e2d7554bb0f1ab': (['URN:NBN:no-nb_digibok_2011120108006'],
#   ['URN:NBN:no-nb_digibok_2008071812003',
#    'URN:NBN:no-nb_digibok_2008031404070']),
#    'URN:NBN:no-nb_digibok_2013082008056',
#    'URN:NBN:no-nb_digibok_2011062208057']),
#  'dd782c32085d3f4d6a1ba5aa71699929958c3b458384bf290078b1cb5bd52bf3': (['URN:NBN:no-nb_digibok_2006081000050',
#    'URN:NBN:no-nb_digibok_2007110601069',
#    'URN:NBN:no-nb_digibok_2010100603002',
#    'URN:NBN:no-nb_digibok_2009050704080',
#    'URN:NBN:no-nb_digibok_2011070620017',
#    'URN:NBN:no-nb_digibok_2009051304105'],
#   ['URN:NBN:no-nb_digibok_2012050806006',
#    'URN:NBN:no-nb_digibok_2014102108198']),
#  '5b2057854505953807486effa5bd382654e9cb54abd0d6f7734ab588b75ce4b5': (['URN:NBN:no-nb_digibok_2009021004142',
#    'URN:NBN:no-nb_digibok_2010091608022',
#    'URN:NBN:no-nb_digibok_2012050806035',
#    'URN:NBN:no-nb_digibok_2012012308213',
#    'URN:NBN:no-nb_digibok_2008021204058',
#    'URN:NBN:no-nb_digibok_2010070505038'],
#   ['URN:NBN:no-nb_digibok_2011022220001',
#    'URN:NBN:no-nb_digibok_2009102010006',
#    'URN:NBN:no-nb_digibok_2014071606003']),
#  'b8da3a53ef9fbb28bf2d85a9ffc5ffc0955ecb91e27d2adc872d6b8f4f445a63': (['URN:NBN:no-nb_digibok_2008021804002',
#    'URN:NBN:no-nb_digibok_2008081200104',
#    'URN:NBN:no-nb_digibok_2008031200066',
#    'URN:NBN:no-nb_digibok_2011070620020',
#    'URN:NBN:no-nb_digibok_2011033012001',
#    'URN:NBN:no-nb_digibok_2009021004142',
#    'URN:NBN:no-nb_digibok_2010091608022',
#    'URN:NBN:no-nb_digibok_2014090408112',
#    'URN:NBN:no-nb_digibok_2013053008055',
#    'URN:NBN:no-nb_digibok_2006082800126',
#    'URN:NBN:no-nb_digibok_2008092504005',
#    'URN:NBN:no-nb_digibok_2012012308213',
#    'URN:NBN:no-nb_digibok_2010102906050'],
#   ['URN:NBN:no-nb_digibok_2014102306003',
#    'URN:NBN:no-nb_digibok_2014101408243',
#    'URN:NBN:no-nb_digibok_2013071508148']),
#  'b11e045249061d23ef785c7515ccad461a53bd7c14320dc5cb584579b6515679': (['URN:NBN:no-nb_digibok_2008021100101',
#    'URN:NBN:no-nb_digibok_2008090300007',
#    'URN:NBN:no-nb_digibok_2012012308213',
#    'URN:NBN:no-nb_digibok_2010090208039',
#    'URN:NBN:no-nb_digibok_2011112808046'],
#   ['URN:NBN:no-nb_digibok_2008121603024',
#    'URN:NBN:no-nb_digibok_2014073005040',
#    'URN:NBN:no-nb_digibok_2014071506052']),
#  '90b9cf2c20ba3ea95714c7a5f51550153db149cdd73e226a6fc200d3245feeb1': (['URN:NBN:no-nb_digibok_2009101510003',
#    'URN:NBN:no-nb_digibok_2010070505038',
#    'URN:NBN:no-nb_digibok_2008021204058',
#    'URN:NBN:no-nb_digibok_2009021000130',
#    'URN:NBN:no-nb_digibok_2008103004018',
#    'URN:NBN:no-nb_digibok_2009102012002',
#    'URN:NBN:no-nb_digibok_2012012308213',
#    'URN:NBN:no-nb_digibok_2012012008212'],
#   ['URN:NBN:no-nb_digibok_2009101510002',
#    'URN:NBN:no-nb_digibok_2009092110004',
#    'URN:NBN:no-nb_digibok_2009092910004',
#    'URN:NBN:no-nb_digibok_2014071606003',
#    'URN:NBN:no-nb_digibok_2010050403036',
#    'URN:NBN:no-nb_digibok_2014021906296']),
#  'f5d955b2abe1c8a65217ba69077392ef7572960aec86cb4b13e64c5fe34996b5': (['URN:NBN:no-nb_digibok_2008021204058',
#    'URN:NBN:no-nb_digibok_2012012308213',
#    'URN:NBN:no-nb_digibok_2008103004018',
#    'URN:NBN:no-nb_digibok_2009021000130',
#    'URN:NBN:no-nb_digibok_2010070505038',
#    'URN:NBN:no-nb_digibok_2009102012002'],
#   ['URN:NBN:no-nb_digibok_2009092110004',
#    'URN:NBN:no-nb_digibok_2014071606003',
#    'URN:NBN:no-nb_digibok_2014021906296',
#    'URN:NBN:no-nb_digibok_2010050403036',
#    'URN:NBN:no-nb_digibok_2011062712001']),
#  '843403e872fa302fdc640bd1c4994cb32dabb07bd727797e94b103e9c90d7f8c': (['URN:NBN:no-nb_digibok_2008103004018',
#    'URN:NBN:no-nb_digibok_2008031200066',
#    'URN:NBN:no-nb_digibok_2012012308213',
#    'URN:NBN:no-nb_digibok_2009021004142',
#    'URN:NBN:no-nb_digibok_2010091608022',
#    'URN:NBN:no-nb_digibok_2013053008055'],
#   ['URN:NBN:no-nb_digibok_2010050403036',
#    'URN:NBN:no-nb_digibok_2014102306003',
#    'URN:NBN:no-nb_digibok_2009092312001',
#    'URN:NBN:no-nb_digibok_2009092110004']),
#  '46abad8d08382817cfaa0af848cfed252b3d586241d834dad7ccbfc0f9ade381': (['URN:NBN:no-nb_digibok_2006082800099',
#    'URN:NBN:no-nb_digibok_2012012308213',
#    'URN:NBN:no-nb_digibok_2008082904033',
#    'URN:NBN:no-nb_digibok_2013053008055',
#    'URN:NBN:no-nb_digibok_2010090208035'],
#   ['URN:NBN:no-nb_digibok_2006082500032',
#    'URN:NBN:no-nb_digibok_2014102306003']),
#  '536c0f5cddd2a1f54c3a8f520989d5f35105cda0cce06568bad1ba5115120d72': (['URN:NBN:no-nb_digibok_2010091608022',
#    'URN:NBN:no-nb_digibok_2009021004142',
#    'URN:NBN:no-nb_digibok_2009111012006',
#    'URN:NBN:no-nb_digibok_2008031200066',
#    'URN:NBN:no-nb_digibok_2010070505038'],
#   ['URN:NBN:no-nb_digibok_2014071606003',
#    'URN:NBN:no-nb_digibok_2009111112009']),
#  '15c6bc46d364727413e0ff9962a44c9e16d1671cc6e99f98e4a1a87e975facf7': (['URN:NBN:no-nb_digibok_2012041308029',
#    'URN:NBN:no-nb_digibok_2008082904033',
#    'URN:NBN:no-nb_digibok_2010032213008',
#    'URN:NBN:no-nb_digibok_2013053008055',
#    'URN:NBN:no-nb_digibok_2008031200066',
#    'URN:NBN:no-nb_digibok_2011101208058',
#    'URN:NBN:no-nb_digibok_2012010508003',
#    'URN:NBN:no-nb_digibok_2007082201033',
#    'URN:NBN:no-nb_digibok_2010090208035',
#    'URN:NBN:no-nb_digibok_2007102900031',
#    'URN:NBN:no-nb_digibok_2014100708075',
#    'URN:NBN:no-nb_digibok_2008092504040',
#    'URN:NBN:no-nb_digibok_2011031120024'],
#   ['URN:NBN:no-nb_digibok_2014102306003']),
#  '4b691ca39e2a5db42b9d55e3c2064fce175f97f4f66be89e727a5cc29861dc38': (['URN:NBN:no-nb_digibok_2013053008055',
#    'URN:NBN:no-nb_digibok_2008031200066',
#    'URN:NBN:no-nb_digibok_2009110310001',
#    'URN:NBN:no-nb_digibok_2010032213008',
#    'URN:NBN:no-nb_digibok_2014111708093',
#    'URN:NBN:no-nb_digibok_2007102900031',
#    'URN:NBN:no-nb_digibok_2007082201033',
#    'URN:NBN:no-nb_digibok_2010090208035',
#    'URN:NBN:no-nb_digibok_2008082904033',
#    'URN:NBN:no-nb_digibok_2006082900010'],
#   ['URN:NBN:no-nb_digibok_2009102212008',
#    'URN:NBN:no-nb_digibok_2014102306003']),
#  'fab60f1351fe737ca8c26e23fc82d29a945e98e24d3e4346515b72e9c6284cf4': (['URN:NBN:no-nb_digibok_2011101408135',
#    'URN:NBN:no-nb_digibok_2010032213007'],
#   ['URN:NBN:no-nb_digibok_2012060106021',
#    'URN:NBN:no-nb_digibok_2010052806015']),
#  '27455af1a1109f1655988c8e37952b433781cac14b92cc2e280349a06020cdac': (['URN:NBN:no-nb_digibok_2012030208159'],
#   ['URN:NBN:no-nb_digibok_2006082900118']),
#  '943d032ef0f13a06385a7912cb7115beb42981425fbb06f467f29309e464e884': (['URN:NBN:no-nb_digibok_2006081100010'],
#   ['URN:NBN:no-nb_digibok_2008062004038']),
#  '4db6c6aad543ca7259a37a987c4f0b1bbee1cbf87be6b11fea153fd0df4add3d': (['URN:NBN:no-nb_digibok_2012011808057'],
#   ['URN:NBN:no-nb_digibok_2006081700046']),
#  'ae1a88bbc0e926087c2713b8e5fe48b1dd03775dfca5a75558380a9216d4fe5e': (['URN:NBN:no-nb_digibok_2007110104005'],
#   ['URN:NBN:no-nb_digibok_2014090308001']),
#  '84ca64d0270426990a666390b00b5f0d0e254c0c6894bc99ce9124d59e6ab0ca': (['URN:NBN:no-nb_digibok_2006083100104',
#    'URN:NBN:no-nb_digibok_2010061403046',
#    'URN:NBN:no-nb_digibok_2008080500045',
#    'URN:NBN:no-nb_digibok_2011070620010',
#    'URN:NBN:no-nb_digibok_2014032108017'],
#   ['URN:NBN:no-nb_digibok_2009042112003',
#    'URN:NBN:no-nb_digibok_2009042012006']),
#  '4f1b0149fcfcb7e614229d6e6987f6d32b1fc7f4933ce02aa7e5d98384d7ad8e': (['URN:NBN:no-nb_digibok_2010070205101',
#    'URN:NBN:no-nb_digibok_2006080900004',
#    'URN:NBN:no-nb_digibok_2007110104005',
#    'URN:NBN:no-nb_digibok_2008080500045',
#    'URN:NBN:no-nb_digibok_2011120508051',
#    'URN:NBN:no-nb_digibok_2012021308024',
#    'URN:NBN:no-nb_digibok_2008011104033',
#    'URN:NBN:no-nb_digibok_2015031106069',
#    'URN:NBN:no-nb_digibok_2011070620010'],
#   ['URN:NBN:no-nb_digibok_2006082400077',
#    'URN:NBN:no-nb_digibok_2014100807576',
#    'URN:NBN:no-nb_digibok_2014102108223',
#    'URN:NBN:no-nb_digibok_2014050908107',
#    'URN:NBN:no-nb_digibok_2014021208010']),
#  '5f966dca3672b0948f66c148a8259562bb33807cb467ce14e86cdb08d206812a': (['URN:NBN:no-nb_digibok_2010102906097',
#    'URN:NBN:no-nb_digibok_2014092308143',
#    'URN:NBN:no-nb_digibok_2008070700052',
#    'URN:NBN:no-nb_digibok_2008022001004',
#    'URN:NBN:no-nb_digibok_2012112206221',
#    'URN:NBN:no-nb_digibok_2011070620007',
#    'URN:NBN:no-nb_digibok_2006083100087',
#    'URN:NBN:no-nb_digibok_2014073108005'],
#   ['URN:NBN:no-nb_digibok_2010111506037',
#    'URN:NBN:no-nb_digibok_2009072812002',
#    'URN:NBN:no-nb_digibok_2014111008005',
#    'URN:NBN:no-nb_digibok_2009072212001',
#    'URN:NBN:no-nb_digibok_2009072912001',
#    'URN:NBN:no-nb_digibok_2014092608039',
#    'URN:NBN:no-nb_digibok_2011032520038',
#    'URN:NBN:no-nb_digibok_2009071712001',
#    'URN:NBN:no-nb_digibok_2009072112001',
#    'URN:NBN:no-nb_digibok_2013042508156']),
#  '366df9fd51cf352330fffdf35eb5cad8fec128e634af69f826897090a27975e6': (['URN:NBN:no-nb_digibok_2015091506126',
#    'URN:NBN:no-nb_digibok_2006083100087'],
#   ['URN:NBN:no-nb_digibok_2007122100036',
#    'URN:NBN:no-nb_digibok_2008040104103',
#    'URN:NBN:no-nb_digibok_2009072412002',
#    'URN:NBN:no-nb_digibok_2014092608039',
#    'URN:NBN:no-nb_digibok_2009072812001',
#    'URN:NBN:no-nb_digibok_2006111400028',
#    'URN:NBN:no-nb_digibok_2008061600099'])}

# %%
with open("ny_gammel_verksid.json", "w") as f:
    json.dump(triple, f)

# %%
dh.CorpusFromIdentifiers([x for y in triple.values() for z in y for x in z]).corpus["authors title year langs".split()].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d41f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >authors</th>
#       <th class="col_heading level0 col1" >title</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >langs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d41f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d41f_row0_col0" class="data row0 col0" >Bjørnson , Bjørnstjerne / Jacobsen , Rolf</td>
#       <td id="T_3d41f_row0_col1" class="data row0 col1" >Jeg velger meg april! : 95 dikt</td>
#       <td id="T_3d41f_row0_col2" class="data row0 col2" >1982</td>
#       <td id="T_3d41f_row0_col3" class="data row0 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d41f_row1_col0" class="data row1 col0" >Bjørnson , Bjørnstjerne / Jacobsen , Rolf</td>
#       <td id="T_3d41f_row1_col1" class="data row1 col1" >Jeg velger meg april! : 95 dikt</td>
#       <td id="T_3d41f_row1_col2" class="data row1 col2" >2000</td>
#       <td id="T_3d41f_row1_col3" class="data row1 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d41f_row2_col0" class="data row2 col0" >Bjørnson , Bjørnstjerne</td>
#       <td id="T_3d41f_row2_col1" class="data row2 col1" >Kongen</td>
#       <td id="T_3d41f_row2_col2" class="data row2 col2" >1885</td>
#       <td id="T_3d41f_row2_col3" class="data row2 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d41f_row3_col0" class="data row3 col0" >Bjørnson , Bjørnstjerne</td>
#       <td id="T_3d41f_row3_col1" class="data row3 col1" >Mellem slagene</td>
#       <td id="T_3d41f_row3_col2" class="data row3 col2" >1957</td>
#       <td id="T_3d41f_row3_col3" class="data row3 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d41f_row4_col0" class="data row4 col0" >Bjørnson , Bjørnstjerne / Skonhoft , Sigurd</td>
#       <td id="T_3d41f_row4_col1" class="data row4 col1" >Mellem slagene</td>
#       <td id="T_3d41f_row4_col2" class="data row4 col2" >1923</td>
#       <td id="T_3d41f_row4_col3" class="data row4 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d41f_row5_col0" class="data row5 col0" >Bjørnson , Bjørnstjerne / Dybwad , Jacob</td>
#       <td id="T_3d41f_row5_col1" class="data row5 col1" >Mellem Slagene : Drama i 1 Akt</td>
#       <td id="T_3d41f_row5_col2" class="data row5 col2" >1858</td>
#       <td id="T_3d41f_row5_col3" class="data row5 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d41f_row6_col0" class="data row6 col0" >Bjørnson , Bjørnstjerne / Sørensen , Henrik</td>
#       <td id="T_3d41f_row6_col1" class="data row6 col1" >Synnøve Solbakken ; Arne</td>
#       <td id="T_3d41f_row6_col2" class="data row6 col2" >1954</td>
#       <td id="T_3d41f_row6_col3" class="data row6 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d41f_row7_col0" class="data row7 col0" >Bjørnson , Bjørnstjerne / Lowzow , Ingrid</td>
#       <td id="T_3d41f_row7_col1" class="data row7 col1" >Bondefortellinger</td>
#       <td id="T_3d41f_row7_col2" class="data row7 col2" >1950</td>
#       <td id="T_3d41f_row7_col3" class="data row7 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3d41f_row8_col0" class="data row8 col0" >Bjørnson , Bjørnstjerne / Seip , Didrik Arup</td>
#       <td id="T_3d41f_row8_col1" class="data row8 col1" >Fortellinger</td>
#       <td id="T_3d41f_row8_col2" class="data row8 col2" >1969</td>
#       <td id="T_3d41f_row8_col3" class="data row8 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3d41f_row9_col0" class="data row9 col0" >Bjørnson , Bjørnstjerne / Sørensen , Henrik</td>
#       <td id="T_3d41f_row9_col1" class="data row9 col1" >Bondefortellinger</td>
#       <td id="T_3d41f_row9_col2" class="data row9 col2" >1957</td>
#       <td id="T_3d41f_row9_col3" class="data row9 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3d41f_row10_col0" class="data row10 col0" >Bjørnson , Bjørnstjerne / Haakonsen , Daniel</td>
#       <td id="T_3d41f_row10_col1" class="data row10 col1" >Synnøve Solbakken</td>
#       <td id="T_3d41f_row10_col2" class="data row10 col2" >1971</td>
#       <td id="T_3d41f_row10_col3" class="data row10 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3d41f_row11_col0" class="data row11 col0" >Bjørnson , Bjørnstjerne</td>
#       <td id="T_3d41f_row11_col1" class="data row11 col1" >Synnøve Solbakken ; Arne ; Fiskerjenten ; Arnljot Gelline</td>
#       <td id="T_3d41f_row11_col2" class="data row11 col2" >1997</td>
#       <td id="T_3d41f_row11_col3" class="data row11 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3d41f_row12_col0" class="data row12 col0" >Bjørnson , Bjørnstjerne / Sørensen , Henrik</td>
#       <td id="T_3d41f_row12_col1" class="data row12 col1" >Synnøve Solbakken</td>
#       <td id="T_3d41f_row12_col2" class="data row12 col2" >1968</td>
#       <td id="T_3d41f_row12_col3" class="data row12 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3d41f_row13_col0" class="data row13 col0" >Bjørnson , Bjørnstjerne / Solum , Sverre</td>
#       <td id="T_3d41f_row13_col1" class="data row13 col1" >Synnøve Solbakken</td>
#       <td id="T_3d41f_row13_col2" class="data row13 col2" >1959</td>
#       <td id="T_3d41f_row13_col3" class="data row13 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3d41f_row14_col0" class="data row14 col0" >Bjørnson , Bjørnstjerne / Sørensen , Henrik</td>
#       <td id="T_3d41f_row14_col1" class="data row14 col1" >Bondefortellinger</td>
#       <td id="T_3d41f_row14_col2" class="data row14 col2" >1963</td>
#       <td id="T_3d41f_row14_col3" class="data row14 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3d41f_row15_col0" class="data row15 col0" >Bjørnson , Bjørnstjerne / Gundersen , Dag / Kittelsen , Th. / Marstrander , Vilhelm / Sørensen , Hans Gerhard / Werenskiold , Erik</td>
#       <td id="T_3d41f_row15_col1" class="data row15 col1" >Bondefortellinger</td>
#       <td id="T_3d41f_row15_col2" class="data row15 col2" >1996</td>
#       <td id="T_3d41f_row15_col3" class="data row15 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3d41f_row16_col0" class="data row16 col0" >Bjørnson , Bjørnstjerne</td>
#       <td id="T_3d41f_row16_col1" class="data row16 col1" >Synnøve Solbakken</td>
#       <td id="T_3d41f_row16_col2" class="data row16 col2" >1982</td>
#       <td id="T_3d41f_row16_col3" class="data row16 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3d41f_row17_col0" class="data row17 col0" >Bjørnson , Bjørnstjerne / Sørensen , Henrik</td>
#       <td id="T_3d41f_row17_col1" class="data row17 col1" >Bondefortællinger</td>
#       <td id="T_3d41f_row17_col2" class="data row17 col2" >1941</td>
#       <td id="T_3d41f_row17_col3" class="data row17 col3" >nob</td>
#     </tr>
#     <tr>
#       <th id="T_3d41f_level0_row18" clas
